# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyan-spec/Pandas-/blob/main/Pands_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Creating** **Dataframe**

# %%
import numpy as np
import pandas as pd

# %%
#using list
student_list = [
    [1,80,100],
    [2,90,70],
    [3,90,70]
]
studentList = pd.DataFrame(student_list, columns=['Roll no.','Marks','IQ'])
studentList
# Out:
#    Roll no.  Marks   IQ
# 0         1     80  100
# 1         2     90   70
# 2         3     90   70

# %%
#using dictionary
student_dict = {
    "Name": ['Ziyan','Sajid','Asif','Anas','Suhel'],
    "Marks": [89,90,78,60,73],
    "Age": [20,21,22,23,21]
}
students = pd.DataFrame(student_dict)
students.set_index('Name',inplace=True)
students
# Out:
#        Marks  Age
# Name
# Ziyan     89   20
# Sajid     90   21
# Asif      78   22
# Anas      60   23
# Suhel     73   21

# %%
#using read_csv
movies = pd.read_csv('/content/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # **DataFrame Attributes and Methods**

# %%
#shape
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
#dtypes
print(movies.dtypes)
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
#index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
#values
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
students.values
# Out:
# array([[89, 20],
#        [90, 21],
#        [78, 22],
#        [60, 23],
#        [73, 21]])

# %%
#head and tail
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
ipl.tail(1)
# Out:
#          ID       City        Date   Season MatchNumber  \
# 949  335982  Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                      Venue                   TossWinner TossDecision  \
# 949  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
#
#     SuperOver            WinningTeam WonBy  Margin method Player_of_Match  \
# 949         N  Kolkata Knight Riders  Runs   140.0    NaN     BB McCullum
#
#                                           Team1Players  \
# 949  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players    Umpire1      Umpire2
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  Asad Rauf  RE Koertzen

# %%
#sample
ipl.sample(3)
# Out:
#           ID     City        Date Season  MatchNumber                Team1  \
# 490   829707  Chennai  2015-04-09   2015            2  Chennai Super Kings
# 17   1304103     Pune  2022-05-10   2022           57       Gujarat Titans
# 553   598072  Kolkata  2013-05-24   2013  Qualifier 2       Mumbai Indians
#
#                     Team2                                          Venue  \
# 490      Delhi Daredevils                MA Chidambaram Stadium, Chepauk
# 17   Lucknow Super Giants  Maharashtra Cricket Association Stadium, Pune
# 553      Rajasthan Royals                                   Eden Gardens
#
#            TossWinner TossDecision SuperOver          WinningTeam    WonBy  \
# 490  Delhi Daredevils        field         N  Chennai Super Kings     Runs
# 17     Gujarat Titans          bat         N       Gujarat Titans     Runs
# 553  Rajasthan Royals          bat         N       Mumbai Indians  Wickets
#
#      Margin method  Player_of_Match  \
# ...

# %%
#info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#describe --> give summary of numerical columns
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
#duplicated  -->check no. of duplicate rows
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
#rename
students
# Out:
#        Marks  Age
# Name
# Ziyan     89   20
# Sajid     90   21
# Asif      78   22
# Anas      60   23
# Suhel     73   21

# %%
students.rename(columns={"Age":"IQ"})
# Out:
#        Marks  IQ
# Name
# Ziyan     89  20
# Sajid     90  21
# Asif      78  22
# Anas      60  23
# Suhel     73  21

# %% [markdown]
# # **Maths Methods**

# %%
#sum
studentList.sum(axis=1)
# Out:
# 0    181
# 1    162
# 2    163
# dtype: int64

# %%
studentList.sum(axis=0)
# Out:
# Roll no.      6
# Marks       260
# IQ          240
# dtype: int64

# %%
studentList.mean()
# Out:
# Roll no.     2.000000
# Marks       86.666667
# IQ          80.000000
# dtype: float64

# %%
studentList.mode(axis=1)
# Out:
#    0   1    2
# 0  1  80  100
# 1  2  70   90
# 2  3  70   90

# %% [markdown]
# # **Selecting columns from DataFrame**

# %%
#single column
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
#multiple columns
ipl[['City','Venue']]
# Out:
#            City                                       Venue
# 0     Ahmedabad            Narendra Modi Stadium, Ahmedabad
# 1     Ahmedabad            Narendra Modi Stadium, Ahmedabad
# 2       Kolkata                       Eden Gardens, Kolkata
# 3       Kolkata                       Eden Gardens, Kolkata
# 4        Mumbai                    Wankhede Stadium, Mumbai
# ..          ...                                         ...
# 945     Kolkata                                Eden Gardens
# 946      Mumbai                            Wankhede Stadium
# 947       Delhi                            Feroz Shah Kotla
# 948  Chandigarh  Punjab Cricket Association Stadium, Mohali
# 949   Bangalore                       M Chinnaswamy Stadium
#
# [950 rows x 2 columns]

# %% [markdown]
# # **Selecting rows from a DataFrame**
#
#
# *   **iloc :** Searches  using index position
# *   **loc :** Searches using index labels

# %%
#single row
movies.iloc[2]   #fetched 2nd row
# Out:
# title_x                          The Accidental Prime Minister (film)
# imdb_id                                                     tt6986710
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/The_Accidental_P...
# title_y                                 The Accidental Prime Minister
# original_title                          The Accidental Prime Minister
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           112
# genres                                                Biography|Drama
# imdb_rating                                                       6.1
# imdb_votes                                                       5549
# story               Based on the memoir by Indian policy analyst S...
# ...

# %%
#multiple rows
movies.iloc[5:11]
# Out:
#                              title_x    imdb_id  \
# 5                        Soni (film)  tt6078866
# 6                      Fraud Saiyaan  tt5013008
# 7                         Bombairiya  tt4971258
# 8   Manikarnika: The Queen of Jhansi  tt6903440
# 9                   Thackeray (film)  tt7777196
# 10                            Amavas  tt8396186
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 5           https://en.wikipedia.org/wiki/Soni_(film)
# 6         https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 7            https://en.wikipedia.org/wiki/Bombairiya
# ...

# %%
#loc
students
# Out:
#        Marks  Age
# Name
# Ziyan     89   20
# Sajid     90   21
# Asif      78   22
# Anas      60   23
# Suhel     73   21

# %%
students.loc['Ziyan']
# Out:
# Marks    89
# Age      20
# Name: Ziyan, dtype: int64

# %%
students.loc['Ziyan':'Anas']    #it includes last one
# Out:
#        Marks  Age
# Name
# Ziyan     89   20
# Sajid     90   21
# Asif      78   22
# Anas      60   23

# %%
#also iloc
students.iloc[:3]
# Out:
#        Marks  Age
# Name
# Ziyan     89   20
# Sajid     90   21
# Asif      78   22

# %%
#fancy indexing
ipl.iloc[[10,24,60]]
# Out:
#          ID         City        Date Season MatchNumber           Team1  \
# 10  1304110  Navi Mumbai  2022-05-16   2022          64  Delhi Capitals
# 24  1304096       Mumbai  2022-05-05   2022          50  Delhi Capitals
# 60  1304060         Pune  2022-04-06   2022          14  Mumbai Indians
#
#                     Team2                                          Venue  \
# 10           Punjab Kings             Dr DY Patil Sports Academy, Mumbai
# 24    Sunrisers Hyderabad                      Brabourne Stadium, Mumbai
# 60  Kolkata Knight Riders  Maharashtra Cricket Association Stadium, Pune
#
#                TossWinner TossDecision SuperOver            WinningTeam  \
# 10           Punjab Kings        field         N         Delhi Capitals
# 24    Sunrisers Hyderabad        field         N         Delhi Capitals
# 60  Kolkata Knight Riders        field         N  Kolkata Knight Riders
#
#       WonBy  Margin method Player_of_Match  \
# 10     Runs    17.0    NaN       SN Thakur
# ...

# %% [markdown]
# # **Selecting both rows and columns**

# %%
ipl.iloc[0:5,0:3]
# Out:
#         ID       City        Date
# 0  1312200  Ahmedabad  2022-05-29
# 1  1312199  Ahmedabad  2022-05-27
# 2  1312198    Kolkata  2022-05-25
# 3  1312197    Kolkata  2022-05-24
# 4  1304116     Mumbai  2022-05-22

# %%
ipl.loc[0:10:2,'ID':'Date']
# Out:
#          ID         City        Date
# 0   1312200    Ahmedabad  2022-05-29
# 2   1312198      Kolkata  2022-05-25
# 4   1304116       Mumbai  2022-05-22
# 6   1304114       Mumbai  2022-05-20
# 8   1304112  Navi Mumbai  2022-05-18
# 10  1304110  Navi Mumbai  2022-05-16

# %% [markdown]
# # **Filtering DataFrame**

# %%
#All the winners in ipl
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
mask = ipl['MatchNumber'] == 'Final'
new_df = ipl[mask]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how many super finishes have occurred
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
#how many matches rcb has won in Kolkata
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Royal Challengers Bangalore')].shape[0]
# Out:
# 5

# %%
#toss winner is match winner in percentage
(ipl[ipl['WinningTeam'] == ipl['TossWinner']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
#movies having rating > 8 and votes > 10000
movies [(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
#action movies with rating > 8.2
mask1 = movies['genres'].str.split('|').apply(lambda x : 'Action' in x)
mask2 = movies['imdb_rating'] > 8.2
movies[mask1 & mask2]
# Out:
#                        title_x    imdb_id  \
# 0     Uri: The Surgical Strike  tt8291224
# 41        Family of Thakurganj  tt8897986
# 219           Raag Desh (film)  tt6080746
# 354              Dangal (film)  tt5074352
# 1058  Black Friday (2007 film)  tt0400234
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 219   https://upload.wikimedia.org/wikipedia/en/thum...
# 354   https://upload.wikimedia.org/wikipedia/en/thum...
# 1058  https://upload.wikimedia.org/wikipedia/en/5/58...
#
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 41    https://en.wikipedia.org/wiki/Family_of_Thakur...
# 219              https://en.wikipedia.org/wiki/Raagdesh
# 354         https://en.wikipedia.org/wiki/Dangal_(film)
# 1058  https://en.wikipedia.org/wiki/Black_Friday_(20...
#
# ...

# %%
#create a function to compare any two teams
def teams(team1,team2):
    pass

# %% [markdown]
# # **Adding new columns**

# %%
#completely new
movies['Country'] = 'India'

# %%
#from existing column
movies.dropna(inplace=True)
movies['Lead actor'] = movies['actors'].str.split().apply(lambda x : x[0])

# %%
movies.head(2)
# Out:
#           title_x    imdb_id  \
# 11      Gully Boy  tt2395469
# 34  Yeh Hai India  tt5525846
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link        title_y original_title  \
# 11      https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy      Gully Boy
# 34  https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India  Yeh Hai India
#
#     is_adult  year_of_release runtime                  genres  imdb_rating  \
# 11         0             2019     153             Drama|Music          8.2
# 34         0             2017     128  Action|Adventure|Drama          5.7
#
#     imdb_votes                                              story  \
# 11       22440  Gully Boy is a film about a 22-year-old boy "M...
# 34         169  Yeh Hai India  follows the story of a 25 years...
#
# ...
